# %% [markdown]
# 1.some common function questions

# %%
##conversion of temperature
def convert_temperature(temp,unit):
    if unit=="C":
        return(temp-32)*5/9
    elif unit=="F":
        return temp*9/5+32
print (convert_temperature(23,"C"))
# Out:
# -5.0

# %% [markdown]
# 2.password checker

# %%
def is_correctpassword(password):
    if len(password)<8:
        return False
    if not any(char.isdigit()for char in password):
        return False
    if not any(char.isupper() for char in password):
        return False
    if not any(char.islower() for char in password):
        return False
    if not any (char in "!@#$%^&*" for char in password):
        return False
    return True
print(is_correctpassword("123ndD!gfggf"))
# Out:
# True

# %% [markdown]
# calculate total cost of item in shopping cart

# %%
def add_numbers(numbers):
    total = 0
    for num in numbers:
        total = total + num
    return total


my_list = [10, 20, 30, 40]

print(add_numbers(my_list))
# Out:
# 100

# %%
###palindrome
def palindrome_checking():
 varr=input("enter a string")
 varr=varr.lower().replace(" ","")
 if varr==varr[::-1]:
    print("the number is palindrome")
 else:
   print("it is not a palindrome number")


palindrome_checking()
# Out:
# it is not a palindrome number

# %%
import os
new_directory="shaubhagya"
os.mkdir(new_directory)
print(f"directory{new_directory}")
# Out:
# directoryshaubhagya

# %%
items=os.listdir('.')
print(items)
# Out:
# ['filehandling', 'linearreg.ipynb', 'package', 'pythonn.ipynb', 'requirements.txt', 'shaubhagya', 'test.py', 'venv']

# %%
dir_namee="folders"
file_name="file.txt"
full_path=os.path.join(os.getcwd(),dir_namee,file_name)
print(full_path)
# Out:
# d:\datascience\folders\file.txt
